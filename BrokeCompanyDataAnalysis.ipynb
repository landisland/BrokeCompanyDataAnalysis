# %% [markdown]
# # 1. Data description
# This dataset is from [Hejing Community ](https://www.kesci.com/mw/dataset/5e023cd12823a10036af49b4/file) and it contains 6272 records, 21 fields, dataset size is 2.3 M.

# %%
import pandas as pd
data = pd.read_csv('/Users/will/Documents/LandislandGithub/DataAnalysis/BrokeCompany/com.csv')

# %%
data.describe()
# Out:
#              bianh    live_days   total_money  Unnamed: 16  Unnamed: 17  \
# count  6272.000000  6272.000000  8.050000e+02          0.0          0.0
# mean    314.100128  1304.558036  1.304852e+04          NaN          NaN
# std     181.071471   646.994339  1.949225e+05          NaN          NaN
# min       1.000000 -4616.000000  0.000000e+00          NaN          NaN
# 25%     157.000000   855.000000  3.000000e+02          NaN          NaN
# 50%     314.000000  1121.000000  6.500000e+02          NaN          NaN
# 75%     471.000000  1674.000000  3.300000e+03          NaN          NaN
# max     628.000000  8622.000000  5.510000e+06          NaN          NaN
#
#        Unnamed: 18  Unnamed: 19  Unnamed: 20
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %% [markdown]
# # 2. Data Visualize & Analysis

# %% [markdown]
# ## 2.1 Broke companies location distribution

# %%
from pyecharts import options as opts
from pyecharts.charts import Map

data['com_addr'] = data['com_addr'].apply(lambda x: x.strip()) # strip can set elements in a series apart
s = data.groupby('com_addr').size()

c = (
Map()
    .add("Number of broke companies", [*s.items()], "china")
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Location distribution"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="02c9cd9e671e415d9940fa39e9903786" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_02c9cd9e671e415d9940fa39e9903786 = echarts.init(
#                     document.getElementById('02c9cd9e671e415d9940fa39e9903786'), 'white', {renderer: 'canvas'});
#                 var option_02c9cd9e671e415d9940fa39e9903786 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Number of broke companies",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1034
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u4e9a\u6d32",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 2239
#                 },
#                 {
#                     "name": "\u5317\u7f8e\u6d32",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 7
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 282
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 51
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1095
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6b27\u6d32",
#                     "value": 3
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 253
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 13
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 19
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 54
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 117
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 52
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 140
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 42
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 72
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 79
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Number of broke companies"
#             ],
#             "selected": {
#                 "Number of broke companies": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Location distribution",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_02c9cd9e671e415d9940fa39e9903786.setOption(option_02c9cd9e671e415d9940fa39e9903786);
#         });
#     </script>

# %% [markdown]
# ## 2.2 Top 10 industries with most broke companies

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.faker import Faker

s = data.groupby('cat').size().sort_values(ascending=False)[:10].to_dict()

c = (
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("Number of broke companies", list(s.values()))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Top 10 industries with most broke companies"),
        legend_opts=opts.LegendOpts(pos_left='70%')
    )
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="587a36bb4a27490f8f1512925ca6852a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_587a36bb4a27490f8f1512925ca6852a = echarts.init(
#                     document.getElementById('587a36bb4a27490f8f1512925ca6852a'), 'white', {renderer: 'canvas'});
#                 var option_587a36bb4a27490f8f1512925ca6852a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Number of broke companies",
#             "legendHoverLink": true,
#             "data": [
#                 925,
#                 789,
#                 595,
#                 510,
#                 500,
#                 421,
#                 376,
#                 374,
#                 334,
#                 311
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Number of broke companies"
#             ],
#             "selected": {
#                 "Number of broke companies": true
#             },
#             "show": true,
#             "left": "70%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u7535\u5b50\u5546\u52a1",
#                 "\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u751f\u6d3b",
#                 "\u91d1\u878d",
#                 "\u793e\u4ea4\u7f51\u7edc",
#                 "\u6587\u5a31\u4f20\u5a92",
#                 "\u6559\u80b2",
#                 "\u5de5\u5177\u8f6f\u4ef6",
#                 "\u6e38\u620f",
#                 "\u6c7d\u8f66\u4ea4\u901a"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Top 10 industries with most broke companies",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_587a36bb4a27490f8f1512925ca6852a.setOption(option_587a36bb4a27490f8f1512925ca6852a);
#         });
#     </script>

# %% [markdown]
# ## 2.3 Top 20 in subdivision

# %%
s = data.groupby('se_cat').size().sort_values(ascending=False)[:20].sort_values(ascending=True).to_dict()

c = (
    Bar()
    .add_xaxis(list(s.keys()))
    .add_yaxis("Number of broke companies", list(s.values()))
    .reversal_axis()
    .set_series_opts(label_opts=opts.LabelOpts(position="right"))
    .set_global_opts(title_opts=opts.TitleOpts(title="Top 20 in subdivision"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5a1a4de777e94f28b74ed6dcf8670ed3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5a1a4de777e94f28b74ed6dcf8670ed3 = echarts.init(
#                     document.getElementById('5a1a4de777e94f28b74ed6dcf8670ed3'), 'white', {renderer: 'canvas'});
#                 var option_5a1a4de777e94f28b74ed6dcf8670ed3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Number of broke companies",
#             "legendHoverLink": true,
#             "data": [
#                 83,
#                 91,
#                 95,
#                 100,
#                 103,
#                 110,
#                 111,
#                 112,
#                 119,
#                 119,
#                 120,
#                 124,
#                 129,
#                 136,
#                 139,
#                 145,
#                 149,
#                 162,
#                 224,
#                 240
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Number of broke companies"
#             ],
#             "selected": {
#                 "Number of broke companies": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u513f\u7ae5\u65e9\u6559",
#                 "\u4e8b\u9879\u53ca\u6548\u7387",
#                 "\u5176\u4ed6\u7535\u5546\u670d\u52a1",
#                 "\u4ea4\u901a\u51fa\u884c",
#                 "\u6574\u5408\u8425\u9500\u4f20\u64ad",
#                 "\u7406\u8d22",
#                 "\u670d\u88c5\u670d\u9970",
#                 "\u5a92\u4f53\u53ca\u9605\u8bfb",
#                 "\u751f\u9c9c\u98df\u54c1",
#                 "\u964c\u751f\u4eba\u4ea4\u53cb",
#                 "\u5176\u4ed6\u4f01\u4e1a\u670d\u52a1",
#                 "\u672c\u5730\u7efc\u5408\u751f\u6d3b",
#                 "\u4eba\u529b\u8d44\u6e90",
#                 "\u7535\u5546\u89e3\u51b3\u65b9\u6848",
#                 "\u5174\u8da3\u793e\u533a",
#                 "\u884c\u4e1a\u4fe1\u606f\u5316\u53ca\u89e3\u51b3\u65b9\u6848",
#                 "\u501f\u8d37",
#                 "\u7f8e\u98df\u9910\u996e",
#                 "\u7efc\u5408\u7535\u5546",
#                 "\u6e38\u620f\u5f00\u53d1\u5546"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "Top 20 in subdivision",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_5a1a4de777e94f28b74ed6dcf8670ed3.setOption(option_5a1a4de777e94f28b74ed6dcf8670ed3);
#         });
#     </script>

# %% [markdown]
# ## 2.4 Year of broke

# %%
data['born_year'] = data['born_data'].apply(lambda x: x[:4])
data['death_year'] = data['death_data'].apply(lambda x: x[:4])
s1 = data.groupby('born_year').size()
s2 = data.groupby('death_year').size()
s1 = pd.DataFrame({'year': s1.index, 'born': s1.values})
s2 = pd.DataFrame({'year': s2.index, 'death': s2.values})
s = pd.merge(s1,s2, on='year', suffixes=['born', 'death'])
s = s[s['year'] > '2008']

c = (
    Bar()
    .add_xaxis( s['year'].to_list())
    .add_yaxis("Number of born companies", s['born'].to_list())
    .add_yaxis("Number of broke companies", s['death'].to_list())
    .set_global_opts(title_opts=opts.TitleOpts(title="Year of broke distribution"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9cb1c86233c54d44b074d3ec6031f1f9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9cb1c86233c54d44b074d3ec6031f1f9 = echarts.init(
#                     document.getElementById('9cb1c86233c54d44b074d3ec6031f1f9'), 'white', {renderer: 'canvas'});
#                 var option_9cb1c86233c54d44b074d3ec6031f1f9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "Number of born companies",
#             "legendHoverLink": true,
#             "data": [
#                 164,
#                 268,
#                 583,
#                 940,
#                 1341,
#                 1410,
#                 944,
#                 252,
#                 34,
#                 6,
#                 1
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "Number of broke companies",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 40,
#                 57,
#                 70,
#                 182,
#                 335,
#                 1131,
#                 1458,
#                 2145,
#                 458,
#                 327
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Number of born companies",
#                 "Number of broke companies"
#             ],
#             "selected": {
#                 "Number of born companies": true,
#                 "Number of broke companies": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2009",
#                 "2010",
#                 "2011",
#                 "2012",
#                 "2013",
#                 "2014",
#                 "2015",
#                 "2016",
#                 "2017",
#                 "2018",
#                 "2019"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Year of broke distribution",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9cb1c86233c54d44b074d3ec6031f1f9.setOption(option_9cb1c86233c54d44b074d3ec6031f1f9);
#         });
#     </script>

# %% [markdown]
# ## 2.5 Length of life of companies

# %%
def live_year(x):
    if x < 365:
        return 'less than 1 year'
    if x < 365 * 2:
        return '1-2 year'
    if x < 365 * 3:
        return '2-3 year'
    if x < 365 * 4:
        return '3-4 year'
    if x < 365 * 5:
        return '4-5 year'
    if x < 365 * 10:
        return '5-10 year'
    return 'more than 10 year'

s = data.groupby(data['live_days'].apply(lambda x: live_year(x))).size()

from pyecharts import options as opts
from pyecharts.charts import Pie

c = (
    Pie()
    .add("", [*s.items()], center=["50%","60%"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Length of life of companies"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"),
                     legend_opts=opts.LegendOpts(pos_top="30%")
                    )
    
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="87c4d616c5864287aff3df8b623de36e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_87c4d616c5864287aff3df8b623de36e = echarts.init(
#                     document.getElementById('87c4d616c5864287aff3df8b623de36e'), 'white', {renderer: 'canvas'});
#                 var option_87c4d616c5864287aff3df8b623de36e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "1-2 year",
#                     "value": 644
#                 },
#                 {
#                     "name": "2-3 year",
#                     "value": 2242
#                 },
#                 {
#                     "name": "3-4 year",
#                     "value": 1108
#                 },
#                 {
#                     "name": "4-5 year",
#                     "value": 954
#                 },
#                 {
#                     "name": "5-10 year",
#                     "value": 1219
#                 },
#                 {
#                     "name": "less than 1 year",
#                     "value": 45
#                 },
#                 {
#                     "name": "more than 10 year",
#                     "value": 60
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "60%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "legend_opts": {
#                 "show": true,
#                 "top": "30%",
#                 "padding": 5,
#                 "itemGap": 10,
#                 "itemWidth": 25,
#                 "itemHeight": 14
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "1-2 year",
#                 "2-3 year",
#                 "3-4 year",
#                 "4-5 year",
#                 "5-10 year",
#                 "less than 1 year",
#                 "more than 10 year"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Length of life of companies",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_87c4d616c5864287aff3df8b623de36e.setOption(option_87c4d616c5864287aff3df8b623de36e);
#         });
#     </script>

# %% [markdown]
# ## 2.6 Investor word cloud

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud
from pyecharts.globals import SymbolType

invest = {}
for row in data['invest_name'].values:
    if not pd.isnull(row):
        for name in row.split('&'):
            invest[name] = invest.get(name, 0) + 1
invest = [*invest.items()]
invest.sort(key=lambda x: x[1], reverse=True)
c = (
    WordCloud()
    .add("", invest[:150], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="Investor word cloud"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="8ac92cc745354a52a5ce2cee36bc764e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_8ac92cc745354a52a5ce2cee36bc764e = echarts.init(
#                     document.getElementById('8ac92cc745354a52a5ce2cee36bc764e'), 'white', {renderer: 'canvas'});
#                 var option_8ac92cc745354a52a5ce2cee36bc764e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u5929\u4f7f\u6e7e",
#                     "value": 32,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(101,86,29)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u771f\u683c\u57fa\u91d1",
#                     "value": 30,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,109,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9669\u5cf0\u957f\u9752",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(125,111,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "IDG\u8d44\u672c",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(139,44,64)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u65b0\u5de5\u573a",
#                     "value": 20,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(132,66,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ecf\u7eac\u4e2d\u56fd",
#                     "value": 18,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(52,87,112)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u6749\u8d44\u672c\u4e2d\u56fd",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(152,29,137)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "PreAngel",
#                     "value": 17,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,52,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6885\u82b1\u521b\u6295",
#                     "value": 16,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(108,20,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6668\u5174\u8d44\u672c",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(94,101,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e5d\u5408\u521b\u6295",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,131,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5947\u864e360",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(92,27,20)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9752\u677e\u57fa\u91d1",
#                     "value": 10,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,10,87)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6d2a\u6cf0\u57fa\u91d1",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(15,95,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6208\u58c1\u521b\u6295",
#                     "value": 9,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(107,88,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u6c83\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,60,26)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u817e\u8baf",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(145,110,132)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u82f1\u8bfa\u5929\u4f7f\u57fa\u91d1",
#                     "value": 8,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(41,68,134)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5fb7\u8fc5\u6295\u8d44",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,120,91)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u7b56\u6e90\u521b\u6295",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(39,59,136)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u4e1a\u63a5\u529b\u5929\u4f7f",
#                     "value": 7,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(74,99,14)"
#                         }
#                     }
#                 },
#                 {

# %% [markdown]
# ## 2.7 Reason of broke word cloud

# %%
death_reason = {}
for row in data['death_reason'].values:
    if not pd.isnull(row):
        for name in row.split(' '):
            death_reason[name] = death_reason.get(name, 0) + 1
c = (
    WordCloud()
    .add("", [*death_reason.items()], word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="Reason of broke word cloud"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="db804d9fe1f443b5927b3f60e3009d6c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_db804d9fe1f443b5927b3f60e3009d6c = echarts.init(
#                     document.getElementById('db804d9fe1f443b5927b3f60e3009d6c'), 'white', {renderer: 'canvas'});
#                 var option_db804d9fe1f443b5927b3f60e3009d6c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "diamond",
#             "rotationRange": [
#                 0,
#                 0
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u653f\u7b56\u76d1\u7ba1",
#                     "value": 88,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(136,25,156)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6cd5\u5f8b\u6cd5\u89c4\u98ce\u9669",
#                     "value": 65,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,103,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u884c\u4e1a\u7ade\u4e89",
#                     "value": 354,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(155,76,81)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u73b0\u91d1\u6d41\u65ad\u88c2",
#                     "value": 116,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(49,151,9)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5546\u4e1a\u6a21\u5f0f\u532e\u4e4f",
#                     "value": 469,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(29,28,128)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u70e7\u94b1",
#                     "value": 83,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,58,12)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8c03\u6574",
#                     "value": 141,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(106,38,37)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5e02\u573a\u4f2a\u9700\u6c42",
#                     "value": 217,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,27,105)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u5165\u573a\u65f6\u673a",
#                     "value": 113,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(147,71,143)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u878d\u8d44\u80fd\u529b\u4e0d\u8db3",
#                     "value": 107,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(69,67,14)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4ea7\u54c1\u7f3a\u9677\u4e25\u91cd",
#                     "value": 31,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(24,111,24)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e1a\u52a1\u8fc7\u4e8e\u5206\u6563",
#                     "value": 63,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,106,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5b9a\u4ef7/\u6210\u672c\u95ee\u9898",
#                     "value": 59,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(122,7,39)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8425\u9500\u4e0d\u8db3",
#                     "value": 44,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(6,84,159)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u521b\u59cb\u4eba\u95ee\u9898",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(40,53,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8f6c\u578b\u95ee\u9898",
#                     "value": 39,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(87,43,127)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u80fd\u529b\u4e0d\u8db3",
#                     "value": 12,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(55,155,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0e\u6295\u8d44\u4eba\u51b2\u7a81",
#                     "value": 5,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(16,45,25)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u56e2\u961f\u7f3a\u4e4f\u6fc0\u60c5",
#                     "value": 2,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(44,14,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4e0d\u91cd\u89c6\u5ba2\u6237",
#                     "value": 11,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(19,83,76)"
#                         }
#                     }
#                 }
#             ],
#             "drawOutOfBound": false,
#             "textStyle": {
#                 "emphasis": {}
#             }
#         }
#     ],
#     "legend": [
